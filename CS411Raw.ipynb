# %%
import pandas as pd

# %%
df = pd.read_csv("US_youtube_trending_data.csv", encoding='utf-8')
df.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
df.shape
# Out:
# (185990, 16)

# %%
df.to_csv("youtube_trending_data_raw.csv", encoding="utf-8", index=False)

# %%
print(df['video_id'].str.len().max())
print(df['title'].str.len().max())
print(df['publishedAt'].str.len().max())
print(df['channelId'].str.len().max())
print(df['channelTitle'].str.len().max())
print(df['trending_date'].str.len().max())
print(df['tags'].str.len().max())
print(df['thumbnail_link'].str.len().max())
print(df['description'].str.len().max())
# Out:
# 11
# 100
# 20
# 24
# 50
# 20
# 500
# 51
# 4998.0

# %%
df_raw = pd.read_csv("youtube_trending_data_raw.csv", engine='python')
df_raw
# Out:
#            video_id                                              title  \
# 0       3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1       M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2       J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3       kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4       VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...             ...                                                ...
# 204366  XgmTqdPd34Y  Austin Butler Searches for Comfort While Eatin...
# 204367  3YT0GKTEbhM                Ryan Seacrest Makes An Announcement
# 204368  4otStedcHBg  Tiger Woods shoots 2-under 69 | Round 1 | Gene...
# 204369  N4xkSFJqBq8  WE GOT AN ALBUM COMING! | NF - HOPE (REACTION!!!)
# 204370  Q9K_j2v0em0    RIP Tony Schnur Thick 44  The Human Man Warrior
#
#                  publishedAt                 channelId      channelTitle  \
# ...

# %%
df_raw.shape
# Out:
# (204371, 16)

# %%
df_raw['title'].isna().sum()
# Out:
# 18381

# %%
df_raw = df_raw[df_raw['title'].notna()]
df_raw.shape
# Out:
# (185990, 16)

# %%
df_raw.to_csv("youtube_trending_data_raw.csv", encoding="utf-8", index=False)

# %%
df_raw_after = pd.read_csv("youtube_trending_data_raw.csv")
df_raw_after.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis        22.0
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends        20.0
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye        24.0
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL        10.0
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate        26.0
#
#           trending_date                                               tags  \
# ...

# %%
df_raw_after.shape
# Out:
# (185990, 16)

# %%
print(df['video_id'].str.len().max())
print(df['title'].str.len().max())
print(df['publishedAt'].str.len().max())
print(df['channelId'].str.len().max())
print(df['channelTitle'].str.len().max())
print(df['trending_date'].str.len().max())
print(df['tags'].str.len().max())
print(df['thumbnail_link'].str.len().max())
print(df['description'].str.len().max())
# Out:
# 11
# 100
# 20
# 24
# 50
# 20
# 500
# 51
# 4998.0

# %% [markdown]
# gcloud sql connect myinstance --user=root
#
# show databases;
#
# use project;

# %% [markdown]
# CREATE TABLE raw_youtube_trending_data(
# videoID VARCHAR(11),
# title VARCHAR(100),
# publishedAT VARCHAR(50),
# channelID VARCHAR(24),
# channelTitle VARCHAR(50),
# categoryID INT,
# trending_date VARCHAR(50),
# tags VARCHAR(500),
# view_count INT,
# likes INT,
# dislikes INT,
# comment_count INT,
# thumbnail_link VARCHAR(100),
# comments_disabled INT,
# ratings_disabled INT,
# description VARCHAR(5000),
# PRIMARY KEY (videoID, trending_date)
# )
